# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
pd.options.display.max_rows = None

# from sklearn.preprocessing import Imputer

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()


raw_data = pd.read_csv('train.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = raw_data.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
age_ishull = df[df['Age'].isnull()]
age_ishull
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
sns.countplot('Survived', data=age_ishull, hue='Sex')

# %%
#df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
sns.pairplot(df)

# %%
#df['Cabin']

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#df['Ticket'].nunique() (=681)

df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin', 'Embarked'], axis=1, inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
df.dropna(inplace=True)
df.reset_index(drop=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %% [markdown]
# ## checkpoint dropped data

# %%
df_new = df.copy() 
df_new.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
sns.pairplot(df_new, hue='Sex', diag_kind='hist')

# %%
sns.pairplot(df_new, hue='Pclass', diag_kind='hist')

# %%
sns.countplot('Sex', data=df_new)

# %%
sns.countplot('Survived', data=df_new, hue='Sex')

# %%
sns.countplot('Survived', data=df_new, hue='Pclass')

# %%
#df_new.count().iplot(kind='bar')

# %%
under_10 = df['Age'] < 10
under_20 = df['Age'] < 20
under_30 = df['Age'] < 30
under_40 = df['Age'] < 40
under_50 = df['Age'] < 50
under_60 = df['Age'] < 60
under_70 = df['Age'] < 70
over_70 = df['Age'] >= 70

age_10under = df[under_10]
age_10_20 = df[under_20 ^ under_10]
age_20_30 = df[under_30 ^ under_20]
age_30_40 = df[under_40 ^ under_30]
age_40_50 = df[under_50 ^ under_40]
age_50_60 = df[under_60 ^ under_50]
age_60_70 = df[under_70 ^ under_60]
age_70up = df[over_70]

male = df[df['Sex'] == 'male']
female = df[df['Sex'] == 'female']

# %%
sns.countplot('Survived', data=kid, hue='Sex')

# １２歳未満の生存者の割合は変わらず

# %%
sns.countplot('Survived', data=young, hue='Sex')

# １２歳以上３０未満　男性死亡、女性生存 (３０歳以上５０未満と逆転)

# %%
sns.countplot('Survived', data=adult, hue='Sex')

# ３０歳以上５０未満　男性生存、女性死亡 (１２歳以上３０未満と逆転)

# %%
sns.countplot('Survived', data=old, hue='Sex')

# ５０歳以上　男性死亡、女性生存

# %%
fig, ax = plt.subplots()
axes1 = ax.hist('Age', data=age_10under, label='Male', alpha=0.7, stacked=['age_10under', 'age_10_20'])
#axes2 = ax.hist('Age', data=female, label='Female', alpha=0.7)

ax.set_ylabel('Count')
ax.set_xlabel('Age')
ax.legend()

# %%
# Out:
# pandas.core.series.Series
